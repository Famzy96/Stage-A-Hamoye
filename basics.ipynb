# %%
import pandas as pd

fd = pd.read_csv('fuel_ferc1.csv', error_bad_lines=False)
fuel_data = pd.read_csv('fuel_ferc1.csv', error_bad_lines=False)
fd.head(10)
# Out:
#                 record_id  utility_id_ferc1  report_year  \
# 0   f1_fuel_1994_12_1_0_7                 1         1994
# 1  f1_fuel_1994_12_1_0_10                 1         1994
# 2   f1_fuel_1994_12_2_0_1                 2         1994
# 3   f1_fuel_1994_12_2_0_7                 2         1994
# 4  f1_fuel_1994_12_2_0_10                 2         1994
# 5  f1_fuel_1994_12_2_0_13                 2         1994
# 6   f1_fuel_1994_12_2_1_1                 2         1994
# 7  f1_fuel_1994_12_2_1_10                 2         1994
# 8  f1_fuel_1994_12_2_2_10                 2         1994
# 9   f1_fuel_1994_12_4_0_1                 4         1994
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0              rockport                coal       ton        5377489.0
# 1  rockport total plant                coal       ton       10486945.0
# 2                gorgas                coal       ton        2978683.0
# ...

# %%
#print the columns only

print(fd.columns)
# Out:
# Index(['record_id', 'utility_id_ferc1', 'report_year', 'plant_name_ferc1',
#        'fuel_type_code_pudl', 'fuel_unit', 'fuel_qty_burned',
#        'fuel_mmbtu_per_unit', 'fuel_cost_per_unit_burned',
#        'fuel_cost_per_unit_delivered', 'fuel_cost_per_mmbtu'],
#       dtype='object')

# %%
fd.describe()
# Out:
#        utility_id_ferc1   report_year  fuel_qty_burned  fuel_mmbtu_per_unit  \
# count      29523.000000  29523.000000     2.952300e+04         29523.000000
# mean         118.601836   2005.806050     2.622119e+06             8.492111
# std           74.178353      7.025483     9.118004e+06            10.600220
# min            1.000000   1994.000000     1.000000e+00             0.000001
# 25%           55.000000   2000.000000     1.381700e+04             1.024000
# 50%          122.000000   2006.000000     2.533220e+05             5.762694
# 75%          176.000000   2012.000000     1.424034e+06            17.006000
# max          514.000000   2018.000000     5.558942e+08           341.260000
#
#        fuel_cost_per_unit_burned  fuel_cost_per_unit_delivered  \
# count               29523.000000                  2.952300e+04
# mean                  208.649031                  9.175704e+02
# std                  2854.490090                  6.877593e+04
# ...

# %%
fd['total'] = fd['utility_id_ferc1'] + fd['report_year']

print(fd)
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 0        f1_fuel_1994_12_1_0_7                 1         1994
# 1       f1_fuel_1994_12_1_0_10                 1         1994
# 2        f1_fuel_1994_12_2_0_1                 2         1994
# 3        f1_fuel_1994_12_2_0_7                 2         1994
# 4       f1_fuel_1994_12_2_0_10                 2         1994
# ...                        ...               ...          ...
# 29518  f1_fuel_2018_12_12_0_13                12         2018
# 29519   f1_fuel_2018_12_12_1_1                12         2018
# 29520  f1_fuel_2018_12_12_1_10                12         2018
# 29521  f1_fuel_2018_12_12_1_13                12         2018
# 29522  f1_fuel_2018_12_12_1_14                12         2018
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                  rockport                coal       ton        5377489.0
# ...

# %%
fd.head()
# Out:
#                 record_id  utility_id_ferc1  report_year  \
# 0   f1_fuel_1994_12_1_0_7                 1         1994
# 1  f1_fuel_1994_12_1_0_10                 1         1994
# 2   f1_fuel_1994_12_2_0_1                 2         1994
# 3   f1_fuel_1994_12_2_0_7                 2         1994
# 4  f1_fuel_1994_12_2_0_10                 2         1994
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0              rockport                coal       ton        5377489.0
# 1  rockport total plant                coal       ton       10486945.0
# 2                gorgas                coal       ton        2978683.0
# 3                 barry                coal       ton        3739484.0
# 4             chickasaw                 gas       mcf          40533.0
#
#    fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# 0               16.590                      18.59
# 1               16.592                      18.58
# ...

# %%
fd.duplicated().any()
# Out:
# False

# %%
fd.isnull().sum()
# Out:
# record_id                         0
# utility_id_ferc1                  0
# report_year                       0
# plant_name_ferc1                  0
# fuel_type_code_pudl               0
# fuel_unit                       180
# fuel_qty_burned                   0
# fuel_mmbtu_per_unit               0
# fuel_cost_per_unit_burned         0
# fuel_cost_per_unit_delivered      0
# fuel_cost_per_mmbtu               0
# dtype: int64

# %%
fd.groupby('fuel_unit')['fuel_unit'].count()
# Out:
# fuel_unit
# bbl        7998
# gal          84
# gramsU      464
# kgU         110
# mcf       11354
# mmbtu       180
# mwdth        95
# mwhth       100
# ton        8958
# Name: fuel_unit, dtype: int64

# %%
fd.groupby('fuel_unit').count()
# Out:
#            record_id  utility_id_ferc1  report_year  plant_name_ferc1  \
# fuel_unit
# bbl             7998              7998         7998              7998
# gal               84                84           84                84
# gramsU           464               464          464               464
# kgU              110               110          110               110
# mcf            11354             11354        11354             11354
# mmbtu            180               180          180               180
# mwdth             95                95           95                95
# mwhth            100               100          100               100
# ton             8958              8958         8958              8958
#
#            fuel_type_code_pudl  fuel_qty_burned  fuel_mmbtu_per_unit  \
# fuel_unit
# bbl                       7998             7998                 7998
# gal                         84               84                   84
# ...

# %%
fuel_data[['fuel_unit']] = fuel_data[['fuel_unit']].fillna(value='mcf')

# %%
fuel_data.isnull().sum()
# Out:
# record_id                       0
# utility_id_ferc1                0
# report_year                     0
# plant_name_ferc1                0
# fuel_type_code_pudl             0
# fuel_unit                       0
# fuel_qty_burned                 0
# fuel_mmbtu_per_unit             0
# fuel_cost_per_unit_burned       0
# fuel_cost_per_unit_delivered    0
# fuel_cost_per_mmbtu             0
# dtype: int64

# %%
fuel_data.head()
# Out:
#                 record_id  utility_id_ferc1  report_year  \
# 0   f1_fuel_1994_12_1_0_7                 1         1994
# 1  f1_fuel_1994_12_1_0_10                 1         1994
# 2   f1_fuel_1994_12_2_0_1                 2         1994
# 3   f1_fuel_1994_12_2_0_7                 2         1994
# 4  f1_fuel_1994_12_2_0_10                 2         1994
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0              rockport                coal       ton        5377489.0
# 1  rockport total plant                coal       ton       10486945.0
# 2                gorgas                coal       ton        2978683.0
# 3                 barry                coal       ton        3739484.0
# 4             chickasaw                 gas       mcf          40533.0
#
#    fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# 0               16.590                      18.59
# 1               16.592                      18.58
# ...

# %%
fuel_data.groupby('report_year')['report_year'].count()
# Out:
# report_year
# 1994    1235
# 1995    1201
# 1996    1088
# 1997    1094
# 1998    1107
# 1999    1050
# 2000    1373
# 2001    1356
# 2002    1205
# 2003    1211
# 2004    1192
# 2005    1269
# 2006    1243
# 2007    1264
# 2008    1228
# 2009    1222
# 2010    1261
# 2011    1240
# 2012    1243
# 2013    1199
# 2014    1171
# 2015    1093
# 2016    1034
# 2017     993
# 2018     951
# Name: report_year, dtype: int64

# %%
#group by the fuel type code year and print the first entries in all the groups formed
fuel_data.groupby('fuel_type_code_pudl').first()
# Out:
#                                   record_id  utility_id_ferc1  report_year  \
# fuel_type_code_pudl
# coal                  f1_fuel_1994_12_1_0_7                 1         1994
# gas                  f1_fuel_1994_12_2_0_10                 2         1994
# nuclear               f1_fuel_1994_12_2_1_1                 2         1994
# oil                   f1_fuel_1994_12_6_0_2                 6         1994
# other                f1_fuel_1994_12_11_0_6                11         1994
# waste                 f1_fuel_1994_12_9_0_3                 9         1994
#
#                      plant_name_ferc1 fuel_unit  fuel_qty_burned  \
# fuel_type_code_pudl
# coal                         rockport       ton        5377489.0
# gas                         chickasaw       mcf          40533.0
# nuclear              joseph m. farley       kgU           2260.0
# oil                      clinch river       bbl           6510.0
# other                      w.f. wyman       bbl          55652.0
# ...

# %%
fuel_data.groupby('fuel_type_code_pudl').count()
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# fuel_type_code_pudl
# coal                      8547              8547         8547
# gas                      11486             11486        11486
# nuclear                    818               818          818
# oil                       8064              8064         8064
# other                      167               167          167
# waste                      441               441          441
#
#                      plant_name_ferc1  fuel_unit  fuel_qty_burned  \
# fuel_type_code_pudl
# coal                             8547       8547             8547
# gas                             11486      11486            11486
# nuclear                           818        818              818
# oil                              8064       8064             8064
# other                             167        167              167
# waste                             441        441              441
#
# ...

# %%
fuel_df1 = fuel_data.iloc[0:19000].reset_index(drop=True)
fuel_df2 = fuel_data.iloc[19000:].reset_index(drop=True)

#check that the length of both dataframes sum to the expected length
assert len(fuel_data) == (len(fuel_df1) + len(fuel_df2))

# %%
#an inner merge will lose rows that do not match in both dataframes
pd.merge(fuel_df1, fuel_df2, how="inner")
# Out:
# Empty DataFrame
# Columns: [record_id, utility_id_ferc1, report_year, plant_name_ferc1, fuel_type_code_pudl, fuel_unit, fuel_qty_burned, fuel_mmbtu_per_unit, fuel_cost_per_unit_burned, fuel_cost_per_unit_delivered, fuel_cost_per_mmbtu]
# Index: []

# %%
#an inner merge will lose rows that do not match in both dataframes
pd.merge(fuel_df1, fuel_df2, how="outer")
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 0        f1_fuel_1994_12_1_0_7                 1         1994
# 1       f1_fuel_1994_12_1_0_10                 1         1994
# 2        f1_fuel_1994_12_2_0_1                 2         1994
# 3        f1_fuel_1994_12_2_0_7                 2         1994
# 4       f1_fuel_1994_12_2_0_10                 2         1994
# ...                        ...               ...          ...
# 29518  f1_fuel_2018_12_12_0_13                12         2018
# 29519   f1_fuel_2018_12_12_1_1                12         2018
# 29520  f1_fuel_2018_12_12_1_10                12         2018
# 29521  f1_fuel_2018_12_12_1_13                12         2018
# 29522  f1_fuel_2018_12_12_1_14                12         2018
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                  rockport                coal       ton        5377489.0
# ...

# %%
fuel_data.duplicated().any()
# Out:
# False

# %%
fuel_data.loc['report_year']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'report_year'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-124-826e414c4518> in <module>
# ----> 1 fuel_data.loc['report_year']
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1765
# ...

# %%
fuel_data
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 0        f1_fuel_1994_12_1_0_7                 1         1994
# 1       f1_fuel_1994_12_1_0_10                 1         1994
# 2        f1_fuel_1994_12_2_0_1                 2         1994
# 3        f1_fuel_1994_12_2_0_7                 2         1994
# 4       f1_fuel_1994_12_2_0_10                 2         1994
# ...                        ...               ...          ...
# 29518  f1_fuel_2018_12_12_0_13                12         2018
# 29519   f1_fuel_2018_12_12_1_1                12         2018
# 29520  f1_fuel_2018_12_12_1_10                12         2018
# 29521  f1_fuel_2018_12_12_1_13                12         2018
# 29522  f1_fuel_2018_12_12_1_14                12         2018
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                  rockport                coal       ton        5377489.0
# ...

# %%
fuel_data.isnull().sum()
# Out:
# record_id                         0
# utility_id_ferc1                  0
# report_year                       0
# plant_name_ferc1                  0
# fuel_type_code_pudl               0
# fuel_unit                       180
# fuel_qty_burned                   0
# fuel_mmbtu_per_unit               0
# fuel_cost_per_unit_burned         0
# fuel_cost_per_unit_delivered      0
# fuel_cost_per_mmbtu               0
# dtype: int64

# %%
fd.isnull().sum()
# Out:
# record_id                         0
# utility_id_ferc1                  0
# report_year                       0
# plant_name_ferc1                  0
# fuel_type_code_pudl               0
# fuel_unit                       180
# fuel_qty_burned                   0
# fuel_mmbtu_per_unit               0
# fuel_cost_per_unit_burned         0
# fuel_cost_per_unit_delivered      0
# fuel_cost_per_mmbtu               0
# dtype: int64

# %%
fuel_data.groupby('fuel_unit')['fuel_unit'].count()
# Out:
# fuel_unit
# bbl        7998
# gal          84
# gramsU      464
# kgU         110
# mcf       11354
# mmbtu       180
# mwdth        95
# mwhth       100
# ton        8958
# Name: fuel_unit, dtype: int64

# %%
fuel_data[['fuel_unit']] = fuel_data[['fuel_unit']].fillna(value='mcf')

# %%
fuel_data.isnull().sum()
# Out:
# record_id                       0
# utility_id_ferc1                0
# report_year                     0
# plant_name_ferc1                0
# fuel_type_code_pudl             0
# fuel_unit                       0
# fuel_qty_burned                 0
# fuel_mmbtu_per_unit             0
# fuel_cost_per_unit_burned       0
# fuel_cost_per_unit_delivered    0
# fuel_cost_per_mmbtu             0
# dtype: int64

# %%
fuel_data
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 0        f1_fuel_1994_12_1_0_7                 1         1994
# 1       f1_fuel_1994_12_1_0_10                 1         1994
# 2        f1_fuel_1994_12_2_0_1                 2         1994
# 3        f1_fuel_1994_12_2_0_7                 2         1994
# 4       f1_fuel_1994_12_2_0_10                 2         1994
# ...                        ...               ...          ...
# 29518  f1_fuel_2018_12_12_0_13                12         2018
# 29519   f1_fuel_2018_12_12_1_1                12         2018
# 29520  f1_fuel_2018_12_12_1_10                12         2018
# 29521  f1_fuel_2018_12_12_1_13                12         2018
# 29522  f1_fuel_2018_12_12_1_14                12         2018
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                  rockport                coal       ton        5377489.0
# ...

# %%
fuel_data.round()
fuel_data.loc['report_year']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'report_year'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-128-0b26dfbc0f21> in <module>
#       1 fuel_data.round()
# ----> 2 fuel_data.loc['report_year']
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1765
# ...

# %%
fuel_data[['report_year','fuel_cost_per_unit_burned']]
# Out:
#        report_year  fuel_cost_per_unit_burned
# 0             1994                      18.59
# 1             1994                      18.58
# 2             1994                      39.72
# 3             1994                      47.21
# 4             1994                       2.77
# ...            ...                        ...
# 29518         2018                       4.78
# 29519         2018                       3.65
# 29520         2018                       4.77
# 29521         2018                       3.06
# 29522         2018                       0.00
#
# [29523 rows x 2 columns]

# %%
report_year_2005 = fuel_data.loc[fuel_data['report_year'] == 2005]
report_year_2005
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 13112  f1_fuel_2005_12_134_0_1               134         2005
# 13113  f1_fuel_2005_12_134_0_2               134         2005
# 13114  f1_fuel_2005_12_134_0_4               134         2005
# 13115  f1_fuel_2005_12_134_0_5               134         2005
# 13116  f1_fuel_2005_12_134_0_7               134         2005
# ...                        ...               ...          ...
# 14376   f1_fuel_2005_12_87_1_2                87         2005
# 14377   f1_fuel_2005_12_87_1_4                87         2005
# 14378   f1_fuel_2005_12_87_1_6                87         2005
# 14379   f1_fuel_2005_12_87_1_7                87         2005
# 14380   f1_fuel_2005_12_87_1_9                87         2005
#
#       plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 13112           carbon                coal       ton         673090.0
# 13113           carbon                 oil       bbl           3415.0
# ...

# %%
report_year_2002 = fuel_data.loc[fuel_data['report_year'] == 2002]
report_year_2002
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 9504   f1_fuel_2002_12_195_0_1               195         2002
# 9505   f1_fuel_2002_12_195_0_3               195         2002
# 9506   f1_fuel_2002_12_195_0_4               195         2002
# 9507   f1_fuel_2002_12_195_0_6               195         2002
# 9508   f1_fuel_2002_12_195_0_7               195         2002
# ...                        ...               ...          ...
# 10704   f1_fuel_2002_12_41_2_3                41         2002
# 10705   f1_fuel_2002_12_41_2_6                41         2002
# 10706  f1_fuel_2002_12_41_2_12                41         2002
# 10707  f1_fuel_2002_12_41_2_15                41         2002
# 10708   f1_fuel_2002_12_41_3_3                41         2002
#
#       plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 9504         pulliam 3                coal       ton          82877.0
# 9505         pulliam 3                 gas       mcf          40350.0
# ...

# %%
report_year_2005['fuel_cost_per_unit_burned'].mean()  #mean of ....
# Out:
# 107.11122064617815

# %%
report_year_2002['fuel_cost_per_unit_burned'].mean()  #mean of ....
# Out:
# 101.17936514522812

# %%
fuel_data['fuel_cost_per_unit_burned']
# Out:
# 0        18.59
# 1        18.58
# 2        39.72
# 3        47.21
# 4         2.77
#          ...
# 29518     4.78
# 29519     3.65
# 29520     4.77
# 29521     3.06
# 29522     0.00
# Name: fuel_cost_per_unit_burned, Length: 29523, dtype: float64

# %%
report_year = fuel_data.groupby(['report_year']).mean()
report_year
# Out:
#              utility_id_ferc1  fuel_qty_burned  fuel_mmbtu_per_unit  \
# report_year
# 1994               106.120648     2.724018e+06            10.638098
# 1995               110.139051     3.712067e+06            10.644830
# 1996               108.714154     2.544754e+06            10.778041
# 1997               108.366545     2.813503e+06            10.247632
# 1998               109.845528     3.267453e+06            10.704964
# 1999               108.222857     3.281281e+06            10.558885
# 2000               111.083758     2.472032e+06             9.224475
# 2001               113.521386     2.321402e+06             8.371469
# 2002               120.354357     2.145645e+06             8.304833
# 2003               123.300578     1.888622e+06             8.403746
# 2004               121.123322     1.782547e+06             8.332425
# 2005               121.028369     1.768876e+06             8.135972
# 2006               117.178600     1.957264e+06             8.138090
# ...

# %%
report_year.sort_values('fuel_cost_per_unit_delivered', ascending = False)
# Out:
#              utility_id_ferc1  fuel_qty_burned  fuel_mmbtu_per_unit  \
# report_year
# 1997               108.366545     2.813503e+06            10.247632
# 1996               108.714154     2.544754e+06            10.778041
# 2000               111.083758     2.472032e+06             9.224475
# 2009               118.139116     2.154993e+06             7.688192
# 2018               133.669821     4.178890e+06             6.596546
# 2015               128.591949     3.340131e+06             7.217820
# 1998               109.845528     3.267453e+06            10.704964
# 2014               129.263877     2.700008e+06             7.588334
# 2013               122.082569     2.741505e+06             7.797024
# 2004               121.123322     1.782547e+06             8.332425
# 2016               133.117021     3.693289e+06             6.846478
# 2010               117.992863     2.423720e+06             7.575013
# 1994               106.120648     2.724018e+06            10.638098
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x = fuel_data['report_year']
y = fuel_data['utility_id_ferc1']


plt.plot(x,y)
plt.show()
